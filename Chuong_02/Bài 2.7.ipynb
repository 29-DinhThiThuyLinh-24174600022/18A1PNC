# %% [markdown]
# Bài 2.7

# %%
import json

json_data = '''
{
    "ten": "Nguyễn Văn A",
    "tuoi": 25,
    "dia_chi": "01 Lê Duẩn, Hà Nội",
    "ky_nang": ["Python", "SQL", "XML"]
}
'''

# Chuyển chuỗi JSON thành đối tượng Python (dict)
python_obj = json.loads(json_data)

#  In ra kết quả
print(python_obj)
print("\n Kiểu dữ liệu:", type(python_obj))
# Out:
# {'ten': 'Nguyễn Văn A', 'tuoi': 25, 'dia_chi': '01 Lê Duẩn, Hà Nội', 'ky_nang': ['Python', 'SQL', 'XML']}
#
#  Kiểu dữ liệu: <class 'dict'>
