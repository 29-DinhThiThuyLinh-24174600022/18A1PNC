# %% [markdown]
# Bài 2.6

# %%
import requests
import xml.etree.ElementTree as ET
import csv

# Tải RSS feed từ URL và lưu thành tệp XML
url = "http://www.hindustantimes.com/rss/topnews/rssfeed.xml"
response = requests.get(url)

with open("rssfeed.xml", "wb") as file:
    file.write(response.content)

print("Đã tải và lưu RSS feed vào rssfeed.xml")

# Phân tích cú pháp tệp XML
tree = ET.parse("rssfeed.xml")
root = tree.getroot()

# Không gian tên (namespace) trong RSS (có thể khác nhau)
# Ta tìm tag 'item' trong RSS
items = []
for item in root.findall(".//item"):
    title = item.find("title").text if item.find("title") is not None else ""
    link = item.find("link").text if item.find("link") is not None else ""
    pubDate = item.find("pubDate").text if item.find("pubDate") is not None else ""
    description = item.find("description").text if item.find("description") is not None else ""
    
    items.append({
        "Title": title,
        "Link": link,
        "PubDate": pubDate,
        "Description": description
    })

print(f"Đã đọc được {len(items)} tin tức từ RSS feed")

# Lưu danh sách tin tức vào file CSV
with open("tin_tuc.csv", "w", newline="", encoding="utf-8") as csvfile:
    fieldnames = ["Title", "Link", "PubDate", "Description"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(items)

print("Đã lưu các mục tin tức vào tin_tuc.csv")
# Out:
# Đã tải và lưu RSS feed vào rssfeed.xml
# Đã đọc được 0 tin tức từ RSS feed
# Đã lưu các mục tin tức vào tin_tuc.csv
