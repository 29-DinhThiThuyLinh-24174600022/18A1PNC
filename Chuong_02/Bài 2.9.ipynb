# %%
import json

cong_ty = {
    "ten_cong_ty": "Công ty TNHH ABC",
    "dia_chi": "01 Lê Duẩn, Hà Nội",
    "giam_doc": "Nguyễn Văn A",
    "dien_thoai": "0865248304",
    "ma_so_thue": "0312345678"
}

json_data = json.dumps(cong_ty, ensure_ascii=False, indent=4, sort_keys=True)

print(json_data)
# Out:
# {
#     "dia_chi": "01 Lê Duẩn, Hà Nội",
#     "dien_thoai": "0865248304",
#     "giam_doc": "Nguyễn Văn A",
#     "ma_so_thue": "0312345678",
#     "ten_cong_ty": "Công ty TNHH ABC"
# }
